# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import h_key
from api_keys import f_key
from api_keys import n_key


# Output File (CSV)
output_data_file = "output_data/hotel.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %% [markdown]
# ### API Calls

# %%
# Create project dataframe (cities)
city_df = pd.read_csv("./Resources/Airport_Output.csv")
city_df.dropna(inplace = True) 
city_df.head()
# Out:
#    Unnamed: 0           City         State        Lat         Lng  \
# 0           0  New York City      New York  40.712775  -74.005973
# 1           1    Los Angeles    California  34.052234 -118.243685
# 2           2        Chicago      Illinois  41.878114  -87.629798
# 3           3        Houston         Texas  29.760427  -95.369803
# 4           4   Philadelphia  Pennsylvania  39.952584  -75.165222
#
#                            Airport Name                   Airport Address  \
# 0  Newark Liberty International Airport             3 Brewster Rd, Newark
# 1     Los Angeles International Airport          1 World Way, Los Angeles
# 2          O'Hare International Airport       10000 W O'Hare Ave, Chicago
# 3              William P. Hobby Airport        7800 Airport Blvd, Houston
# 4    Philadelphia International Airport  8000 Essington Ave, Philadelphia
#
#    Airport Rating Airport Code
# 0             3.2          EWR
# 1             3.5          LAX
# 2             3.6          ORD
# 3             4.0          HOU
# 4             3.3          PHL

# %%
merged_data_path = ("./merged_data.csv")
merged_data_df = pd.read_csv("./merged_data.csv")
merged_data_df.head()
# Out:
#    Unnamed: 0      City   State_x        Lat        Lng  \
# 0         0.0  New York  New York  40.712775 -74.005973
# 1         0.0  New York  New York  40.712775 -74.005973
# 2         0.0  New York  New York  40.712775 -74.005973
# 3         0.0  New York  New York  40.712775 -74.005973
# 4         0.0  New York  New York  40.712775 -74.005973
#
#                            Airport Name        Airport Address  \
# 0  Newark Liberty International Airport  3 Brewster Rd, Newark
# 1  Newark Liberty International Airport  3 Brewster Rd, Newark
# 2  Newark Liberty International Airport  3 Brewster Rd, Newark
# 3  Newark Liberty International Airport  3 Brewster Rd, Newark
# 4  Newark Liberty International Airport  3 Brewster Rd, Newark
#
#    Airport Rating Airport Code  Cheapest_Outbound_Airfare  \
# 0             3.2          EWR                      109.0
# 1             3.2          EWR                      109.0
# 2             3.2          EWR                      109.0
# 3             3.2          EWR                      109.0
# 4             3.2          EWR                      109.0
#
#    Cheapest_Return_Airfare                                              Hotel  \
# 0                    117.0                                      Artezen Hotel
# 1                    117.0                                 World Center Hotel
# 2                    117.0  Fairfield Inn & Suites by Marriott/World Trade...
# 3                    117.0     Holiday Inn Express New York City- Wall Street
# 4                    117.0      Aloft Manhattan Downtown - Financial District
#
#    Rating State_y Country  Price  location             name  rating  \
# 0     4.0      NY      us  87.12  New York  Brooklyn Bridge     4.5
# 1     4.0      NY      us  79.20  New York  Brooklyn Bridge     4.5
# 2     3.0      NY      us  69.30  New York  Brooklyn Bridge     4.5
# 3     3.0      NY      us  74.25  New York  Brooklyn Bridge     4.5
# 4     3.0      NY      us  68.40  New York  Brooklyn Bridge     4.5
#
#    review_count
# 0        1398.0
# 1        1398.0
# 2        1398.0
# 3        1398.0
# 4        1398.0

# %%
mean = merged_data_df.groupby('location')['review_count'].mean()

bar_chart_df = pd.DataFrame({"Mean": mean})
                             
        
bar_chart_df
# Out:
#                  Mean
# location
# Albuquerque     155.0
# Anaheim          50.0
# Anchorage       179.0
# Arlington       203.0
# Atlanta          86.0
# ...               ...
# Tulsa           169.0
# Virginia Beach  127.0
# Washington       64.0
# Wichita          26.0
# Winston-Salem    79.0
#
# [97 rows x 1 columns]

# %%
# Chart our data, give it a title, and label the axes
attraction_chart = bar_chart_df.plot(kind="line",figsize=(20,4), title="Attractions:Location vs Average Review Count")
attraction_chart.set_xlabel("location")
attraction_chart.set_ylabel("review_count")


plt.tight_layout()
plt.savefig("LineGraph_Attraction.png")
plt.show()

# %%
airport_code=[]
cheapestTicketPrice=[]

#outbound trip call
#for index, row in city_df.iterrows():
    #code = row['Airport Code']
    #originplace='BWI'
    #destinationplace=code
    #departure_date="2021-03-15"
    #base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/"
    #tags=originplace + "-sky/" + destinationplace + "-sky/" + departure_date
    #url=base_url + tags
    #print(url)
    #querystring = {"inboundpartialdate":"2021-03-19"}

    #headers = {
        #'x-rapidapi-key': "e5ee88badfmsh65ec7588e95e6fcp181b1cjsn38212393a000",
        #'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
        #}
    #try:
        #response = requests.request("GET", url, headers=headers, params=querystring)
        #response=response.json()
        #airport_code.append(code)
        #cheapestTicketPrice.append(response['Quotes'][0]['MinPrice'])
    #except:
        #cheapestTicketPrice.append('nan')

# %%
#city_df['Cheapest_Outbound_Airfare']=cheapestTicketPrice

# %%
#airport_code=[]
#cheapestTicketPrice=[]
#return trip
#for index, row in city_df.iterrows():
    #code = row['Airport Code']
    #destinationplace='IAD'
    #originplace=code
    #departure_date="2021-03-19"
    #base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/"
    #tags=originplace + "-sky/" + destinationplace + "-sky/" + departure_date
    #url=base_url + tags
    #print(url)
    #querystring = {"inboundpartialdate":"2021-03-19"}

    #headers = {
        #'x-rapidapi-key': "e5ee88badfmsh65ec7588e95e6fcp181b1cjsn38212393a000",
        #'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
        #}
    #try:
        #response = requests.request("GET", url, headers=headers, params=querystring)
        #response=response.json()
        #airport_code.append(code)
        #cheapestTicketPrice.append(response['Quotes'][0]['MinPrice'])
    #except:
        #cheapestTicketPrice.append('nan')

# %%
#city_df['Cheapest_Return_Airfare']=cheapestTicketPrice
#city_df

# %%
#Kayla API LOOP
#counter = 0
#cities = []
#results=[]

    

#For loop
#for city,item in city_df.iterrows():
    #counter=counter+1  
    #print(item)
    #try:
        #url = "https://hotels-com-free.p.rapidapi.com/srle/listing/v1/brands/hotels.com"
        #print(item["Lat"],item["Lng"]) 
        #querystring = {"lat":item["Lat"],"lon":item["Lng"],"checkIn":"2021-03-15","checkOut":"2021-03-19","rooms":"2","locale":"en_US","currency":"USD","pageNumber":"1"}

        #headers = {
        #'x-rapidapi-key': h_key,
        #'x-rapidapi-host': "hotels-com-free.p.rapidapi.com"
        #}

        #response = requests.request("GET", url, headers=headers, params=querystring)

        #response = response.json()
    
#Reading the length of each ref
        #nh = len(response['data']['body']['searchResults']['results'])

       #for i in range(nh):

            #Hotel = response['data']['body']['searchResults']['results'][i]['name']
            #Rating = response['data']['body']['searchResults']['results'][i]['starRating']
            #City = response['data']['body']['searchResults']['results'][i]['address']['locality']
            #State = response['data']['body']['searchResults']['results'][i]['address']['region']
            #Country =response['data']['body']['searchResults']['results'][i]['address']['countryCode']
            #Stay_Rate = response['data']['body']['searchResults']['results'][i]['ratePlan']['price']['exactCurrent']
            
            #results.append([Hotel, Rating,City, State, Country,Stay_Rate])
            
            #time.sleep(2)
            
    #except:
        
        #print("Hotel Data Not Found")
   
               
#print(results)

# %%
#hotel_df = pd.DataFrame(results,columns=["Hotel","Rating","City", "State", "Country","Price"])

#hotel_df.to_csv('HOTEL_API.csv', index=False)

#hotel_df

# %%
#nichole api
#locations = city_df['City'].values.tolist()

# %%
# TODO(uwana): Use your key here. Get it from yelp.com/developers
#api_key= n_key
#headers = {'Authorization': 'Bearer %s' % api_key}
# Using the business search API.
#url='https://api.yelp.com/v3/businesses/search'
#locations
# https://www.yelp.com/developers/documentation/v3/business_search
# All the attractions data
#attractions = []
# Making a get request to the API for each location
#for location in locations:
  # Use query paramaters that conform to the API: https://www.yelp.com/developers/documentation/v3/business_search
  #params = {'term': 'attractions', 'location': location, 'limit': 1, 'sort_by': 'rating'}
  #req = requests.get(url, params=params, headers=headers)
  #data = json.loads(req.text)
  #businesses = data['businesses']
  #for business in businesses:
    #business_info = {'location': location, 'name': business['name'], 'rating': business['rating'],
                    #'review_count': business['review_count']}
    #attractions.append(business_info)
#attractions_json = json.dumps(attractions)
#print(attractions_json)

# %%
#yelp_df = pd.DataFrame(attractions)
#yelp_df.head(100)

# %%
hotel_df = pd.read_csv("HOTEL_API.csv")
hotel_df.head()
# Out:
#                                                Hotel  Rating      City State  \
# 0                                      Artezen Hotel     4.0  New York    NY
# 1                                 World Center Hotel     4.0  New York    NY
# 2  Fairfield Inn & Suites by Marriott/World Trade...     3.0  New York    NY
# 3     Holiday Inn Express New York City- Wall Street     3.0  New York    NY
# 4      Aloft Manhattan Downtown - Financial District     3.0  New York    NY
#
#   Country  Price
# 0      us  87.12
# 1      us  79.20
# 2      us  69.30
# 3      us  74.25
# 4      us  68.40

# %%
#mean = merged_data_df.groupby(‘State_y’)[‘Price’].mean()
#new_city = list(hotel_df['City'])
#print(unique(new_city))
mean = hotel_df.groupby('City')['Price'].mean()
#print(mean)
line_chart_df = pd.DataFrame({"Mean": mean})
#line_chart_df = pd.DataFrame({"Mean": mean})
                             
        
print(line_chart_df)
# Out:
#                       Mean
# City
# Albuquerque      88.848750
# Atlanta          99.905000
# Austin          127.217500
# Baltimore        83.577500
# Boston           99.934286
# Charlotte       132.057500
# Chicago          79.385000
# Ciudad Juarez    54.100000
# Clarksville      65.440000
# Columbus         79.997500
# Dallas          126.817500
# Denver           95.683750
# Detroit         145.407500
# El Paso         116.248333
# Fort Worth       94.481250
# Fresno           71.682500
# Houston         112.416250
# Indianapolis    138.560000
# Jacksonville    121.927500
# Kansas City     103.766250
# Las Vegas        52.497500
# Long Beach      110.267143
# Los Alamitos    109.000000
# Los Angeles      93.001250
# Louisville       92.517143
# Memphis         102.617500
# Mesa             90.902857
# Milwaukee        92.420000
# Nashville       117.808750
# New York         80.407500
# Oklahoma City   104.530000
# Philadelphia    113.492500
# Phoenix         137.180000
# Portland        103.327500
# Quincy           75.000000
# Raleigh          97.657500
# Sacramento      100.355000
# San Antonio     127.223750
# San Diego        95.562500
# San Francisco    82.820000
# San Jose         99.130000
# Seattle         138.418750
# Tempe            62.990000
# Tucson           85.616250
# Virginia Beach   69.102500
# Washington      106.202500

# %%
len(mean)
# Out:
# 46

# %%
len(line_chart_df)
# Out:
# 46

# %%
# Set x axis and tick locations
x_axis = np.arange(len(mean))
tick_locations = [value for value in x_axis]
print(len(tick_locations))
# Out:
# 46

# %%
# Chart our data, give it a title, and label the axes
# Chart our data, give it a title, and label the axes
city_chart = line_chart_df.plot(kind="line",figsize=(20,5), title="Hotel Room Price by City")
city_chart.set_ylabel("Hotel Price ($/Night)")


plt.tight_layout()
plt.savefig("Hotel_linegraph.png")
plt.show()

# %%
line_chart_df.head()
# Out:
#                    City        Mean
# City
# Albuquerque   88.848750   88.848750
# Atlanta       99.905000   99.905000
# Austin       127.217500  127.217500
# Baltimore     83.577500   83.577500
# Boston        99.934286   99.934286

# %%
x_values = north_city_data['lat']
y_values = north_city_data['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.xlabel("Latitude (deg)")
plt.ylabel("Max Temperature (degF)")
print('The R value is: ' + str(rvalue))
print('The R^2 value is: ' + str(rvalue**2))
plt.show()
